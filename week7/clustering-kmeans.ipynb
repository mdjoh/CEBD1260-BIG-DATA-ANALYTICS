# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

sns.set_style('whitegrid')

# %% [markdown]
# # Problem definition

# %% [markdown]
# Cluster counties based on demographic and economic data
#
# https://www.kaggle.com/muonneutrino/us-census-demographic-data/data

# %% [markdown]
# # Load the data

# %%
#input
df = pd.read_csv('data/acs2015_county_data.csv')
df = df.set_index(['CensusId', 'State', 'County']) # clustering using k-means by state and county
df.head()
# Out:
#                           TotalPop    Men  Women  Hispanic  White  Black  \
# CensusId State   County
# 1001     Alabama Autauga     55221  26745  28476       2.6   75.8   18.5
# 1003     Alabama Baldwin    195121  95314  99807       4.5   83.1    9.5
# 1005     Alabama Barbour     26932  14497  12435       4.6   46.2   46.7
# 1007     Alabama Bibb        22604  12073  10531       2.2   74.5   21.4
# 1009     Alabama Blount      57710  28512  29198       8.6   87.9    1.5
#
#                           Native  Asian  Pacific  Citizen      ...       Walk  \
# CensusId State   County                                        ...
# 1001     Alabama Autauga     0.4    1.0      0.0    40725      ...        0.5
# 1003     Alabama Baldwin     0.6    0.7      0.0   147695      ...        1.0
# 1005     Alabama Barbour     0.2    0.4      0.0    20714      ...        1.8
# 1007     Alabama Bibb        0.4    0.1      0.0    17495      ...        0.6
# 1009     Alabama Blount      0.3    0.1      0.0    42345      ...        0.9
#
#                           OtherTransp  WorkAtHome  MeanCommute  Employed  \
# CensusId State   County
# 1001     Alabama Autauga          1.3         1.8         26.5     23986
# 1003     Alabama Baldwin          1.4         3.9         26.4     85953
# 1005     Alabama Barbour          1.5         1.6         24.1      8597
# 1007     Alabama Bibb             1.5         0.7         28.8      8294
# 1009     Alabama Blount           0.4         2.3         34.9     22189
#
#                           PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# CensusId State   County
# 1001     Alabama Autauga         73.6        20.9           5.5         0.0
# 1003     Alabama Baldwin         81.5        12.3           5.8         0.4
# 1005     Alabama Barbour         71.8        20.8           7.3         0.1
# 1007     Alabama Bibb            76.8        16.1           6.7         0.4
# 1009     Alabama Blount          82.0        13.5           4.2         0.4
#
#                           Unemployment
# CensusId State   County
# 1001     Alabama Autauga           7.6
# 1003     Alabama Baldwin           7.5
# 1005     Alabama Barbour          17.6
# 1007     Alabama Bibb              8.3
# 1009     Alabama Blount            7.7
#
# [5 rows x 34 columns]

# %% [markdown]
# # Feature Engineering

# %%
# remove NaNs
df = df.dropna()

# remove column
X_columns = list(df.columns)
if 'IncomeErr' in X_columns:
    X_columns.remove('IncomeErr')
if 'IncomePerCapErr' in X_columns:
    X_columns.remove('IncomePerCapErr')
df = df[X_columns]

# normalize the columns
df_norm = df.copy()
for col in X_columns:
    df_norm[col] = StandardScaler().fit_transform(df_norm[col].values.reshape(-1, 1))

print(df.shape)
df_norm.head()
# Out:
# (3218, 32)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
#                           TotalPop       Men     Women  Hispanic     White  \
# CensusId State   County
# 1001     Alabama Autauga -0.138565 -0.141558 -0.135649 -0.436917  0.015217
# 1003     Alabama Baldwin  0.299519  0.296021  0.302818 -0.338162  0.333734
# 1005     Alabama Barbour -0.227149 -0.219720 -0.234253 -0.332964 -1.276304
# 1007     Alabama Bibb    -0.240702 -0.235189 -0.245956 -0.457708 -0.041505
# 1009     Alabama Blount  -0.130771 -0.130282 -0.131211 -0.125057  0.543170
#
#                              Black    Native     Asian   Pacific   Citizen  \
# CensusId State   County
# 1001     Alabama Autauga  0.688328 -0.182113 -0.085542 -0.182552 -0.142600
# 1003     Alabama Baldwin  0.058063 -0.154533 -0.200496 -0.182552  0.378840
# 1005     Alabama Barbour  2.663158 -0.209694 -0.315449 -0.182552 -0.240147
# 1007     Alabama Bibb     0.891413 -0.182113 -0.430402 -0.182552 -0.255838
# 1009     Alabama Blount  -0.502173 -0.195903 -0.430402 -0.182552 -0.134703
#
#                               ...           Walk  OtherTransp  WorkAtHome  \
# CensusId State   County       ...
# 1001     Alabama Autauga      ...      -0.759868    -0.186826   -0.891579
# 1003     Alabama Baldwin      ...      -0.624686    -0.126385   -0.229682
# 1005     Alabama Barbour      ...      -0.408394    -0.065944   -0.954617
# 1007     Alabama Bibb         ...      -0.732831    -0.065944   -1.238287
# 1009     Alabama Blount       ...      -0.651722    -0.730796   -0.733985
#
#                           MeanCommute  Employed  PrivateWork  PublicWork  \
# CensusId State   County
# 1001     Alabama Autauga     0.574999 -0.144510    -0.081324    0.519837
# 1003     Alabama Baldwin     0.557128  0.269380     0.929400   -0.812026
# 1005     Alabama Barbour     0.146099 -0.247296    -0.311616    0.504350
# 1007     Alabama Bibb        0.986028 -0.249320     0.328083   -0.223528
# 1009     Alabama Blount      2.076149 -0.156513     0.993370   -0.626184
#
#                           SelfEmployed  FamilyWork  Unemployment
# CensusId State   County
# 1001     Alabama Autauga     -0.621632   -0.633383     -0.120902
# 1003     Alabama Baldwin     -0.544978    0.245447     -0.145337
# 1005     Alabama Barbour     -0.161703   -0.413675      2.322651
# 1007     Alabama Bibb        -0.315013    0.245447      0.050147
# 1009     Alabama Blount      -0.953804    0.245447     -0.096466
#
# [5 rows x 32 columns]

# %% [markdown]
# # Model Training

# %%
k = 7
kmeans = KMeans(n_clusters=k).fit(df_norm.values)

print(set(kmeans.labels_))
print(collections.Counter(kmeans.labels_))

df_results = df.copy()
df_norm['cluster'] = kmeans.labels_
df_results['cluster'] = kmeans.labels_
# Out:
# {0, 1, 2, 3, 4, 5, 6}
# Counter({5: 1483, 2: 795, 0: 486, 4: 297, 1: 98, 6: 35, 3: 24})

# %%
# Analyze the results
df_results = df_results.reset_index()
for cluster in sorted(set(kmeans.labels_)):
    print(collections.Counter(df_results[df_results['cluster']==cluster]['State']).most_common(5))

n_clusters = len(set(kmeans.labels_))
for col in X_columns:
    print(col)
    i = 1
    plt.figure(figsize=(16,3))
    for cluster in sorted(set(kmeans.labels_)):
        plt.subplot(1, n_clusters, i)
        plt.xlim([0,df_results[col].max()])
        plt.hist(df_results[df_results['cluster']==cluster][col], label=str(cluster), alpha=0.3, bins=20)
        i += 1
    plt.show()
# Out:
# [('Nebraska', 58), ('Kansas', 54), ('Montana', 43), ('South Dakota', 43), ('North Dakota', 38)]
# [('Puerto Rico', 78), ('Texas', 13), ('New Mexico', 4), ('Arizona', 1), ('California', 1)]
# [('Georgia', 108), ('Texas', 95), ('Mississippi', 69), ('North Carolina', 52), ('Louisiana', 48)]
# [('California', 7), ('New York', 4), ('Texas', 4), ('Florida', 2), ('Arizona', 1)]
# [('Virginia', 27), ('California', 18), ('New Jersey', 18), ('New York', 17), ('Florida', 14)]
# [('Texas', 91), ('Illinois', 87), ('Indiana', 86), ('Iowa', 83), ('Kentucky', 76)]
# [('Alaska', 12), ('South Dakota', 9), ('Montana', 4), ('North Dakota', 3), ('Arizona', 2)]
# TotalPop
# Men
# Women
# Hispanic
# White
# Black
# Native
# Asian
# Pacific
# Citizen
# Income
# IncomePerCap
# Poverty
# ChildPoverty
# Professional
# Service
# Office
# Construction
# Production
# Drive
# Carpool
# Transit
# Walk
# OtherTransp
# WorkAtHome
# MeanCommute
# Employed
# PrivateWork
# PublicWork
# SelfEmployed
# FamilyWork
# Unemployment

# %%
# Analyze the centroids
df_results.groupby('cluster').mean().round(2).T
# Out:
# cluster              0         1         2           3          4         5  \
# CensusId      31353.75  65387.42  28299.93    25117.71   29374.74  31484.42
# TotalPop      10232.54  59114.47  38625.65  2727806.50  431172.70  57061.76
# Men            5182.03  28535.18  19227.41  1337763.42  210933.51  28222.63
# Women          5050.51  30579.29  19398.25  1390043.08  220239.19  28839.13
# Hispanic          8.20     95.54     10.84       32.11      11.99      6.05
# White            86.04      3.67     62.68       39.09      68.28     86.72
# Black             0.99      0.21     22.51       15.39      10.92      3.96
# Native            2.22      0.20      1.45        0.30       0.46      0.69
# Asian             0.66      0.15      0.68       10.32       5.31      0.79
# Pacific           0.08      0.01      0.05        0.19       0.23      0.05
# Citizen        7838.14  39563.38  27799.74  1727242.38  303637.16  42783.07
# Income        47738.79  20895.00  36653.51    58445.54   67494.54  47957.42
# IncomePerCap  26449.27  10862.31  19377.20    30709.17   33878.60  24519.31
# Poverty          13.30     45.56     23.45       17.33      11.84     14.67
# ChildPoverty     17.38     56.34     33.77       24.08      15.47     20.57
# Professional     34.99     28.14     26.82       37.60      41.68     29.78
# Service          17.51     22.97     19.87       19.91      17.00     17.69
# Office           19.62     24.94     21.81       24.17      24.03     22.77
# Construction     15.98     12.08     13.98        7.72       7.79     12.05
# Production       11.89     11.87     17.53       10.60       9.51     17.71
# Drive            71.67     82.33     81.08       64.94      77.47     81.62
# Carpool          10.25      8.91     11.57        9.20       8.89      9.97
# Transit           0.58      0.99      0.53       15.05       4.05      0.49
# Walk              6.69      3.74      2.19        4.04       2.84      2.52
# OtherTransp       1.79      1.61      1.64        2.27       1.79      1.35
# WorkAtHome        9.01      2.43      2.99        4.50       4.95      4.05
# MeanCommute      18.73     26.96     24.65       30.03      26.13     23.33
# Employed       4695.06  19037.77  14974.96  1264473.33  209497.89  25649.61
# PrivateWork      65.17     65.64     73.12       81.48      78.34     78.03
# PublicWork       20.13     26.09     20.07       12.07      15.91     14.63
# SelfEmployed     14.01      8.11      6.59        6.33       5.61      7.11
# FamilyWork        0.69      0.16      0.22        0.13       0.14      0.23
# Unemployment      4.87     17.68     10.70        9.49       7.06      7.12
#
# cluster              6
# CensusId      24607.14
# TotalPop      13600.97
# Men            6845.54
# Women          6755.43
# Hispanic          4.06
# White            27.87
# Black             0.67
# Native           60.81
# Asian             1.82
# Pacific           0.35
# Citizen        9201.97
# Income        41944.86
# IncomePerCap  18966.34
# Poverty          29.43
# ChildPoverty     38.23
# Professional     34.70
# Service          20.39
# Office           19.11
# Construction     14.10
# Production       11.71
# Drive            53.85
# Carpool          11.08
# Transit           1.00
# Walk             17.65
# OtherTransp       7.34
# WorkAtHome        9.10
# MeanCommute      14.31
# Employed       4337.11
# PrivateWork      48.95
# PublicWork       41.42
# SelfEmployed      9.06
# FamilyWork        0.56
# Unemployment     15.96

# %%
# Analyze the results
for col in X_columns:
    print(col)
    for cluster in set(kmeans.labels_):
        plt.hist(df_results[df_results['cluster']==cluster][col], label=str(cluster), alpha=0.3, bins=20)
    plt.legend()
    plt.show()
# Out:
# TotalPop
# Men
# Women
# Hispanic
# White
# Black
# Native
# Asian
# Pacific
# Citizen
# Income
# IncomePerCap
# Poverty
# ChildPoverty
# Professional
# Service
# Office
# Construction
# Production
# Drive
# Carpool
# Transit
# Walk
# OtherTransp
# WorkAtHome
# MeanCommute
# Employed
# PrivateWork
# PublicWork
# SelfEmployed
# FamilyWork
# Unemployment

# %% [markdown]
# # Model Evaluation

# %%
# Inter-Cluster
centroids = []
for cluster in sorted(set(kmeans.labels_)):
    centroids.append(df_norm[df_norm['cluster']==cluster][X_columns].mean().values)
distances = []
for c1 in centroids:
    for c2 in centroids:
        distances.append(euclidean_distances(c1.reshape(-1, 1), c2.reshape(-1, 1))[0][0])
print('Inter Cluster distance', np.mean(distances))

# Intra-Cluster
distances = []
for cluster in sorted(set(kmeans.labels_)):
    df_filter = df_norm[df_norm['cluster']==cluster]
    centroid = df_filter[X_columns].mean().values
    for k, v in df_filter[X_columns].iterrows():
        distances.append(euclidean_distances(centroid.reshape(-1, 1), v.values.reshape(-1, 1))[0][0])
print('Intra Cluster distance', np.mean(distances))

# Inertia
distances = []
for cluster in sorted(set(kmeans.labels_)):
    df_filter = df_norm[df_norm['cluster']==cluster]
    centroid = df_filter[X_columns].mean().values
    for k, v in df_filter[X_columns].iterrows():
        distances.append(euclidean_distances(centroid.reshape(1, -1), v.values.reshape(1, -1), squared=True)[0][0])
print('Inertia', np.sum(distances))
# Out:
# Inter Cluster distance 2.302759682085099
# Intra Cluster distance 0.20219108559869015
# Inertia 60673.956460538364

# %%
inertia = []
number_k = []
for k in range(2, 100, 10):
    kmeans = KMeans(n_clusters=k).fit(df_norm.values)
    inertia.append(kmeans.inertia_)
    number_k.append(k)
plt.plot(number_k, inertia)
plt.show()
